# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import duckdb
df_check = duckdb.sql("SELECT * FROM 'app_daily_metrics.csv' LIMIT 5").df()
df_check
# Out:
#         date app_id   app_name platform region  reach_users  sessions_total  \
# 0 2025-06-02   A001    Vista 1      iOS     UK         2177            3375
# 1 2025-06-02   A001    Vista 1  Android     UK         2673            4610
# 2 2025-06-02   A002  Riviera 2      iOS     UK        12051           25104
# 3 2025-06-02   A002  Riviera 2  Android     UK        22462           22462
# 4 2025-06-02   A003  Quattro 3      iOS     UK         7292           14251
#
#    duration_total_seconds  session_mean_seconds  session_median_seconds
# 0               852544.09                259.94                  188.27
# 1               801294.04                179.12                  140.50
# 2              5697754.97                225.56                  178.59
# 3              4186183.01                185.05                  160.69
# 4              3913287.07                278.30                  217.48

# %%
#To understand my data
df = pd.read_csv('app_daily_metrics.csv')
#df.shape()
df.head()
#df.tail()
#df.describe()
df.dtypes
# Out:
# date                       object
# app_id                     object
# app_name                   object
# platform                   object
# region                     object
# reach_users                 int64
# sessions_total              int64
# duration_total_seconds    float64
# session_mean_seconds      float64
# session_median_seconds    float64
# dtype: object

# %%
#Convert date to date data type

df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date                      datetime64[ns]
# app_id                            object
# app_name                          object
# platform                          object
# region                            object
# reach_users                        int64
# sessions_total                     int64
# duration_total_seconds           float64
# session_mean_seconds             float64
# session_median_seconds           float64
# dtype: object

# %%
df['date'].isnull().sum()
# Out:
# np.int64(0)

# %%
mind = df['date'].min()
print(mind)
# Out:
# 2025-06-02 00:00:00

# %%
maxd = df['date'].max()
print(maxd)
# Out:
# 2025-08-30 00:00:00

# %%
#Check count of unique dates
df['date'].nunique()
# Out:
# 90

# %%
#To check for Completeness at the date level
#Check that the unique date values = the difference between the min and max date values
(maxd - mind).days + 1
# Out:
# 90

# %%
#To check for completeness at the app/platform level

duckdb.sql("""
SELECT app_id
     --,app_name
    ,platform
    ,COUNT(DISTINCT date) AS Dates_Reported
FROM 'app_daily_metrics.csv'
GROUP BY app_id
     ,platform
ORDER BY Dates_Reported


""").df()



duckdb.sql("""
WITH date_spine AS (
    SELECT DISTINCT 
        date 
    FROM 'app_daily_metrics.csv'
),
app_platform AS (
    SELECT DISTINCT 
        app_id
        ,platform
    FROM 'app_daily_metrics.csv'
),
expected AS (
    SELECT 
        a.app_id
        ,a.platform
        ,d.date
    FROM app_platform a
    CROSS JOIN date_spine d
)
SELECT 
    e.app_id
    ,e.platform
    ,e.date
FROM expected e
LEFT JOIN 'app_daily_metrics.csv' actual
    ON e.app_id = actual.app_id
    AND e.platform = actual.platform
    AND e.date = actual.date
WHERE actual.app_id IS NULL
""").df()
# Out:
# Empty DataFrame
# Columns: [app_id, platform, date]
# Index: []

# %%
#To check for duplicates across app_id, platform and date
duckdb.sql("""
SELECT app_id
    ,platform
    ,date
    ,COUNT(*) AS All_Count

FROM 'app_daily_metrics.csv'

GROUP BY app_id
    ,platform
    ,date

HAVING COUNT(*) > 1


""").df()
# Out:
# Empty DataFrame
# Columns: [app_id, platform, date, All_Count]
# Index: []

# %%
#Completeness rule/alert for production - set alert for no missing row

completeness_alert = duckdb.sql("""
WITH date_spine AS (
    SELECT DISTINCT
        date
    FROM 'app_daily_metrics.csv'
),
app_platform AS (
    SELECT DISTINCT
        app_id
        ,platform
    FROM 'app_daily_metrics.csv'
),
expected AS (
    SELECT
        a.app_id
        ,a.platform
        ,d.date
    FROM app_platform a
    CROSS JOIN date_spine d
)
SELECT
    e.app_id
    ,e.platform
    ,e.date AS metric_date
    ,'completeness' AS alert_category
    ,'missing_row' AS alert_type
    ,'critical' AS severity
    ,NULL AS metric_name
    ,NULL AS observed_value
    ,NULL AS expected_value
    ,NULL AS deviation_score
    ,'Expected app_id + platform + date combination has no data' AS description
    ,CURRENT_TIMESTAMP AS detected_at
    
FROM expected e

LEFT JOIN 'app_daily_metrics.csv' actual
    ON e.app_id = actual.app_id
    AND e.platform = actual.platform
    AND e.date = actual.date
    
WHERE actual.app_id IS NULL
""").df()

print(completeness_alert.head())
# Out:
# Empty DataFrame
# Columns: [app_id, platform, metric_date, alert_category, alert_type, severity, metric_name, observed_value, expected_value, deviation_score, description, detected_at]
# Index: []

# %%
#Consistency check - does sessions_mean_seconds * sessions_total reconciles with duration_total-seconds?
#First, I looked at the distribution of the data to determine what the accepted percentage difference should be. Seeing that the max is 0.0309, I picked the percentage diff as 0.0400
#Percentage diff = ((sessions_mean_seconds * sessions_total) - duration_total_seconds) / duration_total_seconds
#Normally to determine this, it would be a decision made with stakeholders with more contectual knowledge.
#Sessions_total ranges from 1736 to 249722, which is a very wide range for a daily count
duckdb.sql("""
SELECT MIN(pct_diff) AS min_diff, MAX(pct_diff) AS max_diff, AVG(pct_diff) AS avg_diff
FROM (
    SELECT ABS(session_mean_seconds * sessions_total - duration_total_seconds) / duration_total_seconds AS pct_diff
    FROM 'app_daily_metrics.csv'
)
""").df()
# Out:
#    min_diff  max_diff  avg_diff
# 0  0.000003  0.030901  0.014814

# %%
#To create a flag column for avg_count
#I picked 0.0400 because it is close to double the average gap, comfortably above the max, without being so loose it'd miss a real 2x-sized anomaly
duckdb.sql("""
With Cal_dur AS
    (SELECT app_id
     ,platform
      ,date
      ,sessions_total
     ,duration_total_seconds
     ,session_mean_seconds
     ,session_median_seconds
     ,session_mean_seconds * sessions_total AS calculated_duration
    FROM 'app_daily_metrics.csv'
    )

SELECT *
     ,ABS(calculated_duration - duration_total_seconds) / duration_total_seconds AS diff_pct
     ,CASE
     WHEN ABS(calculated_duration - duration_total_seconds) / duration_total_seconds < 0.04 THEN 0
     WHEN ABS(calculated_duration - duration_total_seconds) / duration_total_seconds >= 0.04 THEN 1
     ELSE 2
     END AS avg_count_flag
FROM Cal_dur

--WHERE ABS(calculated_duration - duration_total_seconds) / duration_total_seconds >= 0.04 
ORDER BY avg_count_flag DESC;




--SELECT
--     COUNT(*)
 
--FROM 'app_daily_metrics.csv'

--WHERE ABS((session_mean_seconds * sessions_total) - duration_total_seconds) / duration_total_seconds >= 0.02 


""").df()
# Out:
#      app_id platform       date  sessions_total  duration_total_seconds  \
# 0      A001      iOS 2025-06-02            3375               852544.09
# 1      A001  Android 2025-06-02            4610               801294.04
# 2      A002      iOS 2025-06-02           25104              5697754.97
# 3      A002  Android 2025-06-02           22462              4186183.01
# 4      A003      iOS 2025-06-02           14251              3913287.07
# ...     ...      ...        ...             ...                     ...
# 3595   A018  Android 2025-08-30           29260              7525194.63
# 3596   A019      iOS 2025-08-30           97500             22549191.02
# 3597   A019  Android 2025-08-30          105091             21085223.99
# 3598   A020      iOS 2025-08-30           22196              4302941.92
# 3599   A020  Android 2025-08-30           10694              2760774.67
#
#       session_mean_seconds  session_median_seconds  calculated_duration  \
# 0                   259.94                  188.27            877297.50
# 1                   179.12                  140.50            825743.20
# 2                   225.56                  178.59           5662458.24
# 3                   185.05                  160.69           4156593.10
# 4                   278.30                  217.48           3966053.30
# ...                    ...                     ...                  ...
# 3595                259.15                  159.87           7582729.00
# 3596                225.93                  165.69          22028175.00
# 3597                197.94                  168.84          20801712.54
# 3598                190.51                  141.25           4228559.96
# 3599                256.79                  144.22           2746112.26
#
#       diff_pct  avg_count_flag
# 0     0.029035               0
# 1     0.030512               0
# 2     0.006195               0
# 3     0.007068               0
# 4     0.013484               0
# ...        ...             ...
# 3595  0.007646               0
# 3596  0.023106               0
# 3597  0.013446               0
# 3598  0.017286               0
# 3599  0.005311               0
#
# [3600 rows x 10 columns]

# %%
#Consistency rule/alert for production - check that session_mean_seconds * sessions_total is close to the valure of duration_total_seconds
duration_mismatch_alert = duckdb.sql("""

With cal_dur AS (
    SELECT app_id, platform, date,
           duration_total_seconds, session_mean_seconds, session_median_seconds, sessions_total,
           session_mean_seconds * sessions_total AS calculated_duration
    FROM 'app_daily_metrics.csv'
),

diff AS (
    SELECT *,
           ABS(calculated_duration - duration_total_seconds) / duration_total_seconds AS pct_diff
    FROM cal_dur
)

SELECT
    app_id, platform, date AS metric_date,
    'consistency' AS alert_category,
    'duration_reconciliation_mismatch' AS alert_type,
    'warning' AS severity,
    'session_mean_seconds * sessions_total vs duration_total_seconds' AS metric_name,
    pct_diff AS observed_value,
    0.04 AS expected_value,
    NULL AS deviation_score,
    'Calculated duration from mean and session count does not reconcile with duration_total_seconds within 4% tolerance' AS description,
    CURRENT_TIMESTAMP AS detected_at
    
FROM diff

WHERE pct_diff >= 0.04


""").df()

print(duration_mismatch_alert.head())
# Out:
# Empty DataFrame
# Columns: [app_id, platform, metric_date, alert_category, alert_type, severity, metric_name, observed_value, expected_value, deviation_score, description, detected_at]
# Index: []

# %%
#Consistency check - does distinct reach_users equals or exceed sessions_total?
#
duckdb.sql("""
With tableCC AS
(SELECT app_id
    ,platform
    ,date
    ,reach_users
    ,sessions_total
    ,CASE
        WHEN reach_users <= sessions_total THEN 0
        ELSE 1
    END AS reach_users_flag

FROM 'app_daily_metrics.csv'
)

SELECT *

FROM tableCC

ORDER BY reach_users_flag DESC



""").df()
# Out:
#      app_id platform       date  reach_users  sessions_total  reach_users_flag
# 0      A001      iOS 2025-06-02         2177            3375                 0
# 1      A001  Android 2025-06-02         2673            4610                 0
# 2      A002      iOS 2025-06-02        12051           25104                 0
# 3      A002  Android 2025-06-02        22462           22462                 0
# 4      A003      iOS 2025-06-02         7292           14251                 0
# ...     ...      ...        ...          ...             ...               ...
# 3595   A018  Android 2025-08-30        13836           29260                 0
# 3596   A019      iOS 2025-08-30        70366           97500                 0
# 3597   A019  Android 2025-08-30        63664          105091                 0
# 3598   A020      iOS 2025-08-30         9620           22196                 0
# 3599   A020  Android 2025-08-30         8077           10694                 0
#
# [3600 rows x 6 columns]

# %%
#Consistency rule/alert for production - check if distinct reach_users equals or exceed sessions_total 
users_exceeds_sessions = duckdb.sql("""
WITH tableCC AS (
    SELECT app_id
            ,platform
            ,date
           ,reach_users
           ,sessions_total
           
    FROM 'app_daily_metrics.csv'
),

diff AS (
    SELECT *,
           reach_users > sessions_total AS users_exceeds_sessions
    FROM tableCC
)

SELECT  app_id
    ,platform 
    ,date AS metric_date,
    'consistency' AS alert_category,
    'users_exceeds_sessions' AS alert_type,
    'critical' AS severity,
    'reach_users vs sessions_total' AS metric_name,
    reach_users AS observed_value,
    sessions_total AS expected_value,
    NULL AS deviation_score,
    'reach_users exceeds sessions_total, which is not logically possible' AS description,
    CURRENT_TIMESTAMP AS detected_at
    
FROM diff

WHERE users_exceeds_sessions



""").df()

print(users_exceeds_sessions.head())
# Out:
# Empty DataFrame
# Columns: [app_id, platform, metric_date, alert_category, alert_type, severity, metric_name, observed_value, expected_value, deviation_score, description, detected_at]
# Index: []

# %%
#Consistency check - does session_median_seconds vs session_mean_seconds fall off a wide range
#

duckdb.sql("""
SELECT MIN(Avg_mean_medium)
    ,MAX(Avg_mean_medium)
    ,AVG(Avg_mean_medium)

FROM (SELECT
    session_mean_seconds/session_median_seconds AS Avg_mean_medium
    
    
FROM 'app_daily_metrics.csv'
)





""").df()
# Out:
#    min(Avg_mean_medium)  max(Avg_mean_medium)  avg(Avg_mean_medium)
# 0               0.64256              4.287311              1.359993

# %%
#To check the top 5 and bottom 5 rows for patterns out of the ordinary
duckdb.sql("""

SELECT *

FROM (SELECT app_id
    ,platform
    ,date
    ,sessions_total
    ,session_mean_seconds
    ,session_median_seconds,
    session_median_seconds / session_mean_seconds AS ratio

FROM 'app_daily_metrics.csv'

)

ORDER BY ratio DESC
--ORDER BY ratio 

LIMIT 5 

""").df()
# Out:
#   app_id platform       date  sessions_total  session_mean_seconds  \
# 0   A017  Android 2025-08-16           70338                 75.70
# 1   A005  Android 2025-08-07           17126                 69.70
# 2   A011  Android 2025-07-31           25579                 30.00
# 3   A010  Android 2025-06-26            7561                128.59
# 4   A020      iOS 2025-07-12            6242                110.38
#
#    session_median_seconds     ratio
# 0                  117.81  1.556275
# 1                  106.03  1.521234
# 2                   39.88  1.329333
# 3                  163.13  1.268606
# 4                  137.75  1.247962

# %%
#since the observed ratio falls into 0.23 – 1.56 range, I set my flag threshhold as < 0.15 and > 1.65.
#
duckdb.sql("""
SELECT *
    ,CASE
        WHEN med_mean_ratio < 0.15 OR med_mean_ratio > 1.65 THEN 1
        ELSE 0
    END AS med_mean_flag

FROM (SELECT app_id
    ,platform
    ,date
    ,sessions_total
    ,session_mean_seconds
    ,session_median_seconds,
    session_median_seconds / session_mean_seconds AS med_mean_ratio

FROM 'app_daily_metrics.csv'

)

ORDER BY med_mean_flag DESC




""").df()
# Out:
#      app_id platform       date  sessions_total  session_mean_seconds  \
# 0      A001      iOS 2025-06-02            3375                259.94
# 1      A001  Android 2025-06-02            4610                179.12
# 2      A002      iOS 2025-06-02           25104                225.56
# 3      A002  Android 2025-06-02           22462                185.05
# 4      A003      iOS 2025-06-02           14251                278.30
# ...     ...      ...        ...             ...                   ...
# 3595   A018  Android 2025-08-30           29260                259.15
# 3596   A019      iOS 2025-08-30           97500                225.93
# 3597   A019  Android 2025-08-30          105091                197.94
# 3598   A020      iOS 2025-08-30           22196                190.51
# 3599   A020  Android 2025-08-30           10694                256.79
#
#       session_median_seconds  med_mean_ratio  med_mean_flag
# 0                     188.27        0.724283              0
# 1                     140.50        0.784390              0
# 2                     178.59        0.791763              0
# 3                     160.69        0.868360              0
# 4                     217.48        0.781459              0
# ...                      ...             ...            ...
# 3595                  159.87        0.616901              0
# 3596                  165.69        0.733369              0
# 3597                  168.84        0.852986              0
# 3598                  141.25        0.741431              0
# 3599                  144.22        0.561626              0
#
# [3600 rows x 8 columns]

# %%
#Consistency rule/alert for production - does session_median_seconds vs session_mean_seconds fall off a wide range

med_mean_alert = duckdb.sql("""
With med_mean AS
(
    SELECT app_id
           ,platform
           ,date
           ,sessions_total, session_mean_seconds, session_median_seconds
           ,session_median_seconds / session_mean_seconds AS ratio
    FROM 'app_daily_metrics.csv'
)

SELECT
    app_id
   ,platform
   ,date AS metric_date
   ,'consistency' AS alert_category
   ,'median_mean_ratio_outlier' AS alert_type
   ,'warning' AS severity
   ,'session_median_seconds / session_mean_seconds' AS metric_name
   ,ratio AS observed_value
   ,NULL AS expected_value
   ,NULL AS deviation_score
   ,'Median_mean session length ratio outside expected 0.15-1.65 range' AS description
   ,CURRENT_TIMESTAMP AS detected_at
    
FROM med_mean

WHERE ratio < 0.15 OR ratio > 1.65

""").df()


print(med_mean_alert.head())
# Out:
# Empty DataFrame
# Columns: [app_id, platform, metric_date, alert_category, alert_type, severity, metric_name, observed_value, expected_value, deviation_score, description, detected_at]
# Index: []

# %%
duckdb.sql("""
SELECT app_id
        ,platform
        ,date
        ,reach_users
        ,rolling_mean
        ,rolling_stddev
        ,z_score
FROM (
    SELECT *,
        (reach_users - rolling_mean) / rolling_stddev AS z_score
    FROM (
        SELECT app_id
            ,platform
            ,date
            ,reach_users
            ,AVG(reach_users) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS rolling_mean
            ,STDDEV(reach_users) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS rolling_stddev
        FROM 'app_daily_metrics.csv'
    )
)
ORDER BY z_score DESC
LIMIT 10
""").df()
# Out:
#   app_id platform       date  reach_users  rolling_mean  rolling_stddev  \
# 0   A004  Android 2025-06-04        55384  35915.000000      855.599205
# 1   A005  Android 2025-08-03        21286   7747.107143     1111.533187
# 2   A018  Android 2025-07-16        35005  12010.571429     2586.289727
# 3   A004  Android 2025-06-19       118533  48874.882353     9022.145760
# 4   A009      iOS 2025-06-14        76817  31254.083333     6082.508431
# 5   A011  Android 2025-08-02        32283  16268.571429     2256.390914
# 6   A006  Android 2025-07-06        80213  30566.214286     7457.901926
# 7   A005  Android 2025-06-27        15610   7267.360000     1280.442563
# 8   A016  Android 2025-07-31       116920  51270.821429    10543.263523
# 9   A013  Android 2025-07-27        95731  36897.392857     9870.810141
#
#      z_score
# 0  22.754813
# 1  12.180377
# 2   8.890894
# 3   7.720793
# 4   7.490810
# 5   7.097364
# 6   6.656937
# 7   6.515435
# 8   6.226647
# 9   5.960363

# %%
#Z_score giving untrustable numbers so I ensured that it require a minimum number of prior days before trusting a z-score

duckdb.sql("""

With windowed AS (
    SELECT app_id
        ,platform
        ,date
        ,reach_users
        ,AVG(reach_users) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS rolling_mean
        ,STDDEV(reach_users) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS rolling_stddev
        ,COUNT(reach_users) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS prior_days_count
    FROM 'app_daily_metrics.csv'
)
SELECT *,
    CASE
        WHEN prior_days_count >= 14 THEN (reach_users - rolling_mean) / rolling_stddev
        ELSE NULL
    END AS z_score
    
FROM windowed

ORDER BY app_id, platform, date

""").df()
# Out:
#      app_id platform       date  reach_users  rolling_mean  rolling_stddev  \
# 0      A001  Android 2025-06-02         2673           NaN             NaN
# 1      A001  Android 2025-06-03         2340   2673.000000             NaN
# 2      A001  Android 2025-06-04         2531   2506.500000      235.466558
# 3      A001  Android 2025-06-05         2501   2514.666667      167.099771
# 4      A001  Android 2025-06-06         2654   2511.250000      136.607406
# ...     ...      ...        ...          ...           ...             ...
# 3595   A020      iOS 2025-08-26         6682   7499.678571     1368.574713
# 3596   A020      iOS 2025-08-27         7534   7560.285714     1288.310000
# 3597   A020      iOS 2025-08-28         6216   7507.178571     1256.112258
# 3598   A020      iOS 2025-08-29         8727   7523.035714     1236.038220
# 3599   A020      iOS 2025-08-30         9620   7551.500000     1254.791808
#
#       prior_days_count   z_score
# 0                    0       NaN
# 1                    1       NaN
# 2                    2       NaN
# 3                    3       NaN
# 4                    4       NaN
# ...                ...       ...
# 3595                28 -0.597467
# 3596                28 -0.020403
# 3597                28 -1.027917
# 3598                28  0.974051
# 3599                28  1.648481
#
# [3600 rows x 8 columns]

# %%
#To detect anomaly using rolling mean and std dev for the preceding 28 days.
#Added in the 14days - prior_days_count because it's the number of days that should pass before I can trust the Z_score. Before the 14 days, the z_score was outrageous.

duckdb.sql("""
SELECT MIN(z_score) AS min_z
        ,MAX(z_score) AS max_z
        ,AVG(z_score) AS avg_z
        ,COUNT(*) AS valid_rows
        
FROM (
    WITH windowed AS (
        SELECT app_id
           ,platform
           ,date
           ,reach_users
           ,AVG(reach_users) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS rolling_mean
           ,STDDEV(reach_users) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS rolling_stddev
           ,COUNT(reach_users) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS prior_days_count
        FROM 'app_daily_metrics.csv'
    )
    SELECT *,
        CASE
            WHEN prior_days_count >= 14 THEN (reach_users - rolling_mean) / rolling_stddev
            ELSE NULL
        END AS z_score
    FROM windowed
)
WHERE z_score IS NOT NULL
""").df()
# Out:
#       min_z      max_z     avg_z  valid_rows
# 0 -4.576757  12.180377  0.089053        3040

# %%
#To convert the anomaly alert to a function for reusability.

def detect_anomaly(metric_column, min_history_days=14, z_threshold=3):
    query = f"""
    WITH windowed AS (
        SELECT app_id
            ,platform
            ,date
            ,{metric_column}
            ,AVG({metric_column}) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS rolling_mean
            ,STDDEV({metric_column}) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS rolling_stddev
            ,COUNT({metric_column}) OVER (PARTITION BY app_id, platform ORDER BY date ROWS BETWEEN 28 PRECEDING AND 1 PRECEDING) AS prior_days_count
        
        FROM 'app_daily_metrics.csv'
    ),
    scored AS (
        SELECT *,
            CASE WHEN prior_days_count >= {min_history_days}
                 THEN ({metric_column} - rolling_mean) / rolling_stddev
                 ELSE NULL
            END AS z_score
        FROM windowed
    )
    SELECT
        app_id
        ,platform
        ,date AS metric_date
        ,'anomaly' AS alert_category
       ,'{metric_column}_zscore_outlier' AS alert_type
       ,CASE WHEN ABS(z_score) >= 5 THEN 'critical' ELSE 'warning' END AS severity
       ,'{metric_column} rolling z-score' AS metric_name
       ,{metric_column} AS observed_value
       ,rolling_mean AS expected_value
       ,z_score AS deviation_score
       ,'{metric_column} is more than {z_threshold} standard deviations from its 28-day rolling baseline' AS description
       ,CURRENT_TIMESTAMP AS detected_at
    FROM scored
    WHERE ABS(z_score) >= {z_threshold}
    """
    return duckdb.sql(query).df()


anomaly_alert_v2 = detect_anomaly('reach_users')
print(anomaly_alert_v2.shape)  


sessions_anomaly = detect_anomaly('sessions_total')
print(sessions_anomaly.shape)
# Out:
# (51, 12)
# (44, 12)

# %%
#To replace the original sql query with the reusable detect_anomaly() function.
# Tested to produce identical output (51 rows, 12 columns) to the original before swapping in,


anomaly_alert = detect_anomaly('reach_users')
print(anomaly_alert.shape)
# Out:
# (51, 12)

# %%
#To confirm known genuine anomalies (traced back individually during development) appear in the final output

anomaly_alert[anomaly_alert['app_id'].isin(['A004', 'A005', 'A018'])]
# Out:
#    app_id platform metric_date alert_category                  alert_type  \
# 27   A005      iOS  2025-08-12        anomaly  reach_users_zscore_outlier
# 30   A005  Android  2025-06-21        anomaly  reach_users_zscore_outlier
# 31   A005  Android  2025-06-27        anomaly  reach_users_zscore_outlier
# 32   A005  Android  2025-08-03        anomaly  reach_users_zscore_outlier
# 34   A004  Android  2025-06-19        anomaly  reach_users_zscore_outlier
# 39   A018  Android  2025-07-05        anomaly  reach_users_zscore_outlier
# 40   A018  Android  2025-07-08        anomaly  reach_users_zscore_outlier
# 41   A018  Android  2025-07-16        anomaly  reach_users_zscore_outlier
# 44   A018      iOS  2025-07-13        anomaly  reach_users_zscore_outlier
# 45   A018      iOS  2025-08-09        anomaly  reach_users_zscore_outlier
#
#     severity                  metric_name  observed_value  expected_value  \
# 27   warning  reach_users rolling z-score            1665     6311.357143
# 30   warning  reach_users rolling z-score           10636     6933.894737
# 31  critical  reach_users rolling z-score           15610     7267.360000
# 32  critical  reach_users rolling z-score           21286     7747.107143
# 34  critical  reach_users rolling z-score          118533    48874.882353
# 39   warning  reach_users rolling z-score           16994    11612.642857
# 40   warning  reach_users rolling z-score            3595    11915.178571
# 41  critical  reach_users rolling z-score           35005    12010.571429
# 44   warning  reach_users rolling z-score           16132    10489.571429
# 45   warning  reach_users rolling z-score           21147    10530.357143
#
#     deviation_score                                        description  \
# 27        -3.970355  reach_users is more than 3 standard deviations...
# 30         3.588299  reach_users is more than 3 standard deviations...
# 31         6.515435  reach_users is more than 3 standard deviations...
# 32        12.180377  reach_users is more than 3 standard deviations...
# 34         7.720793  reach_users is more than 3 standard deviations...
# 39         3.127306  reach_users is more than 3 standard deviations...
# 40        -3.991580  reach_users is more than 3 standard deviations...
# 41         8.890894  reach_users is more than 3 standard deviations...
# 44         3.282611  reach_users is more than 3 standard deviations...
# 45         3.742657  reach_users is more than 3 standard deviations...
#
#                         detected_at
# 27 2026-09-04 11:05:23.063305+01:00
# 30 2026-09-04 11:05:23.063305+01:00
# 31 2026-09-04 11:05:23.063305+01:00
# 32 2026-09-04 11:05:23.063305+01:00
# 34 2026-09-04 11:05:23.063305+01:00
# 39 2026-09-04 11:05:23.063305+01:00
# 40 2026-09-04 11:05:23.063305+01:00
# 41 2026-09-04 11:05:23.063305+01:00
# 44 2026-09-04 11:05:23.063305+01:00
# 45 2026-09-04 11:05:23.063305+01:00

# %%
#To combine all alerts to one table so the DQ check for completeness, consistency and anomaly could be in a place

alerts_df = pd.concat([
        completeness_alert
        ,duration_mismatch_alert
        ,users_exceeds_sessions
        ,med_mean_alert
        ,anomaly_alert
], ignore_index= True)

alerts_df.insert(0, 'alert_id', range(1, len(alerts_df) + 1))

print(alerts_df.shape)
alerts_df
# Out:
# (51, 13)
#     alert_id app_id platform metric_date alert_category  \
# 0          1   A001      iOS  2025-07-02        anomaly
# 1          2   A001      iOS  2025-07-09        anomaly
# 2          3   A006  Android  2025-06-25        anomaly
# 3          4   A006  Android  2025-07-06        anomaly
# 4          5   A006  Android  2025-07-28        anomaly
# 5          6   A001  Android  2025-08-09        anomaly
# 6          7   A006      iOS  2025-07-09        anomaly
# 7          8   A009  Android  2025-08-20        anomaly
# 8          9   A011      iOS  2025-07-10        anomaly
# 9         10   A011      iOS  2025-08-15        anomaly
# 10        11   A013  Android  2025-07-05        anomaly
# 11        12   A013  Android  2025-07-13        anomaly
# 12        13   A013  Android  2025-07-26        anomaly
# 13        14   A013  Android  2025-07-27        anomaly
# 14        15   A016      iOS  2025-06-23        anomaly
# 15        16   A020  Android  2025-07-21        anomaly
# 16        17   A020  Android  2025-08-23        anomaly
# 17        18   A017      iOS  2025-07-28        anomaly
# 18        19   A017      iOS  2025-08-27        anomaly
# 19        20   A002  Android  2025-08-19        anomaly
# 20        21   A014      iOS  2025-06-19        anomaly
# 21        22   A014      iOS  2025-08-04        anomaly
# 22        23   A003      iOS  2025-08-21        anomaly
# 23        24   A015  Android  2025-07-05        anomaly
# 24        25   A015  Android  2025-07-11        anomaly
# 25        26   A015  Android  2025-07-15        anomaly
# 26        27   A015  Android  2025-08-24        anomaly
# 27        28   A005      iOS  2025-08-12        anomaly
# 28        29   A010      iOS  2025-06-23        anomaly
# 29        30   A019      iOS  2025-06-27        anomaly
# 30        31   A005  Android  2025-06-21        anomaly
# 31        32   A005  Android  2025-06-27        anomaly
# 32        33   A005  Android  2025-08-03        anomaly
# 33        34   A010  Android  2025-08-22        anomaly
# 34        35   A004  Android  2025-06-19        anomaly
# 35        36   A007      iOS  2025-07-13        anomaly
# 36        37   A007      iOS  2025-08-25        anomaly
# 37        38   A008      iOS  2025-06-28        anomaly
# 38        39   A008      iOS  2025-08-09        anomaly
# 39        40   A018  Android  2025-07-05        anomaly
# 40        41   A018  Android  2025-07-08        anomaly
# 41        42   A018  Android  2025-07-16        anomaly
# 42        43   A008  Android  2025-08-03        anomaly
# 43        44   A008  Android  2025-08-23        anomaly
# 44        45   A018      iOS  2025-07-13        anomaly
# 45        46   A018      iOS  2025-08-09        anomaly
# 46        47   A011  Android  2025-08-02        anomaly
# 47        48   A016  Android  2025-06-22        anomaly
# 48        49   A016  Android  2025-07-22        anomaly
# 49        50   A016  Android  2025-07-31        anomaly
# 50        51   A020      iOS  2025-06-23        anomaly
#
#                     alert_type  severity                  metric_name  \
# 0   reach_users_zscore_outlier  critical  reach_users rolling z-score
# 1   reach_users_zscore_outlier   warning  reach_users rolling z-score
# 2   reach_users_zscore_outlier   warning  reach_users rolling z-score
# 3   reach_users_zscore_outlier  critical  reach_users rolling z-score
# 4   reach_users_zscore_outlier   warning  reach_users rolling z-score
# 5   reach_users_zscore_outlier   warning  reach_users rolling z-score
# 6   reach_users_zscore_outlier   warning  reach_users rolling z-score
# 7   reach_users_zscore_outlier   warning  reach_users rolling z-score
# 8   reach_users_zscore_outlier   warning  reach_users rolling z-score
# 9   reach_users_zscore_outlier   warning  reach_users rolling z-score
# 10  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 11  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 12  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 13  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 14  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 15  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 16  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 17  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 18  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 19  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 20  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 21  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 22  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 23  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 24  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 25  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 26  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 27  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 28  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 29  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 30  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 31  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 32  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 33  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 34  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 35  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 36  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 37  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 38  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 39  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 40  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 41  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 42  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 43  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 44  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 45  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 46  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 47  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 48  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 49  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 50  reach_users_zscore_outlier   warning  reach_users rolling z-score
#
#     observed_value  expected_value  deviation_score  \
# 0           4291.0     2408.714286         5.581063
# 1            851.0     2520.642857        -3.427630
# 2           8918.0    31165.347826        -3.725334
# 3          80213.0    30566.214286         6.656937
# 4          72403.0    32635.714286         3.376455
# 5           4617.0     3033.071429         3.189606
# 6          38309.0    26598.607143         3.283769
# 7          66700.0    39172.142857         4.980478
# 8          17474.0    11843.357143         3.043646
# 9          22071.0    12609.000000         4.553457
# 10         49123.0    32154.607143         3.317125
# 11         60664.0    33796.678571         4.623232
# 12         62378.0    35779.714286         3.105810
# 13         95731.0    36897.392857         5.960363
# 14         73887.0    42273.238095         3.625367
# 15          3615.0     8815.750000        -4.576757
# 16         13093.0     8548.035714         3.609510
# 17         44665.0    21279.321429         4.865400
# 18         34345.0    21021.857143         3.597016
# 19          6349.0    19793.107143        -3.484417
# 20          8315.0    17569.705882        -3.043881
# 21          5389.0    18514.892857        -3.100160
# 22         17626.0    10024.250000         4.401954
# 23         84910.0    53262.642857         3.068118
# 24         17262.0    53071.821429        -3.186745
# 25        129544.0    52198.821429         5.915078
# 26         95176.0    60462.464286         3.240653
# 27          1665.0     6311.357143        -3.970355
# 28          1487.0     2571.857143        -3.362413
# 29         67724.0    44894.760000         3.018831
# 30         10636.0     6933.894737         3.588299
# 31         15610.0     7267.360000         6.515435
# 32         21286.0     7747.107143        12.180377
# 33          1547.0     3111.428571        -4.358748
# 34        118533.0    48874.882353         7.720793
# 35          5955.0     2677.107143         5.365140
# 36          1391.0     2829.964286        -3.240462
# 37         21500.0    13277.000000         3.181089
# 38         22651.0    14733.964286         4.026172
# 39         16994.0    11612.642857         3.127306
# 40          3595.0    11915.178571        -3.991580
# 41         35005.0    12010.571429         8.890894
# 42         23174.0    16556.857143         3.025281
# 43         25365.0    17125.500000         3.901965
# 44         16132.0    10489.571429         3.282611
# 45         21147.0    10530.357143         3.742657
# 46         32283.0    16268.571429         7.097364
# 47         89771.0    49190.750000         5.177816
# 48         20346.0    50047.142857        -3.440646
# 49        116920.0    51270.821429         6.226647
# 50         13154.0     7215.285714         4.375855
#
#                                           description  \
# 0   reach_users is more than 3 standard deviations...
# 1   reach_users is more than 3 standard deviations...
# 2   reach_users is more than 3 standard deviations...
# 3   reach_users is more than 3 standard deviations...
# 4   reach_users is more than 3 standard deviations...
# 5   reach_users is more than 3 standard deviations...
# 6   reach_users is more than 3 standard deviations...
# 7   reach_users is more than 3 standard deviations...
# 8   reach_users is more than 3 standard deviations...
# 9   reach_users is more than 3 standard deviations...
# 10  reach_users is more than 3 standard deviations...
# 11  reach_users is more than 3 standard deviations...
# 12  reach_users is more than 3 standard deviations...
# 13  reach_users is more than 3 standard deviations...
# 14  reach_users is more than 3 standard deviations...
# 15  reach_users is more than 3 standard deviations...
# 16  reach_users is more than 3 standard deviations...
# 17  reach_users is more than 3 standard deviations...
# 18  reach_users is more than 3 standard deviations...
# 19  reach_users is more than 3 standard deviations...
# 20  reach_users is more than 3 standard deviations...
# 21  reach_users is more than 3 standard deviations...
# 22  reach_users is more than 3 standard deviations...
# 23  reach_users is more than 3 standard deviations...
# 24  reach_users is more than 3 standard deviations...
# 25  reach_users is more than 3 standard deviations...
# 26  reach_users is more than 3 standard deviations...
# 27  reach_users is more than 3 standard deviations...
# 28  reach_users is more than 3 standard deviations...
# 29  reach_users is more than 3 standard deviations...
# 30  reach_users is more than 3 standard deviations...
# 31  reach_users is more than 3 standard deviations...
# 32  reach_users is more than 3 standard deviations...
# 33  reach_users is more than 3 standard deviations...
# 34  reach_users is more than 3 standard deviations...
# 35  reach_users is more than 3 standard deviations...
# 36  reach_users is more than 3 standard deviations...
# 37  reach_users is more than 3 standard deviations...
# 38  reach_users is more than 3 standard deviations...
# 39  reach_users is more than 3 standard deviations...
# 40  reach_users is more than 3 standard deviations...
# 41  reach_users is more than 3 standard deviations...
# 42  reach_users is more than 3 standard deviations...
# 43  reach_users is more than 3 standard deviations...
# 44  reach_users is more than 3 standard deviations...
# 45  reach_users is more than 3 standard deviations...
# 46  reach_users is more than 3 standard deviations...
# 47  reach_users is more than 3 standard deviations...
# 48  reach_users is more than 3 standard deviations...
# 49  reach_users is more than 3 standard deviations...
# 50  reach_users is more than 3 standard deviations...
#
#                         detected_at
# 0  2026-09-04 11:05:23.063305+01:00
# 1  2026-09-04 11:05:23.063305+01:00
# 2  2026-09-04 11:05:23.063305+01:00
# 3  2026-09-04 11:05:23.063305+01:00
# 4  2026-09-04 11:05:23.063305+01:00
# 5  2026-09-04 11:05:23.063305+01:00
# 6  2026-09-04 11:05:23.063305+01:00
# 7  2026-09-04 11:05:23.063305+01:00
# 8  2026-09-04 11:05:23.063305+01:00
# 9  2026-09-04 11:05:23.063305+01:00
# 10 2026-09-04 11:05:23.063305+01:00
# 11 2026-09-04 11:05:23.063305+01:00
# 12 2026-09-04 11:05:23.063305+01:00
# 13 2026-09-04 11:05:23.063305+01:00
# 14 2026-09-04 11:05:23.063305+01:00
# 15 2026-09-04 11:05:23.063305+01:00
# 16 2026-09-04 11:05:23.063305+01:00
# 17 2026-09-04 11:05:23.063305+01:00
# 18 2026-09-04 11:05:23.063305+01:00
# 19 2026-09-04 11:05:23.063305+01:00
# 20 2026-09-04 11:05:23.063305+01:00
# 21 2026-09-04 11:05:23.063305+01:00
# 22 2026-09-04 11:05:23.063305+01:00
# 23 2026-09-04 11:05:23.063305+01:00
# 24 2026-09-04 11:05:23.063305+01:00
# 25 2026-09-04 11:05:23.063305+01:00
# 26 2026-09-04 11:05:23.063305+01:00
# 27 2026-09-04 11:05:23.063305+01:00
# 28 2026-09-04 11:05:23.063305+01:00
# 29 2026-09-04 11:05:23.063305+01:00
# 30 2026-09-04 11:05:23.063305+01:00
# 31 2026-09-04 11:05:23.063305+01:00
# 32 2026-09-04 11:05:23.063305+01:00
# 33 2026-09-04 11:05:23.063305+01:00
# 34 2026-09-04 11:05:23.063305+01:00
# 35 2026-09-04 11:05:23.063305+01:00
# 36 2026-09-04 11:05:23.063305+01:00
# 37 2026-09-04 11:05:23.063305+01:00
# 38 2026-09-04 11:05:23.063305+01:00
# 39 2026-09-04 11:05:23.063305+01:00
# 40 2026-09-04 11:05:23.063305+01:00
# 41 2026-09-04 11:05:23.063305+01:00
# 42 2026-09-04 11:05:23.063305+01:00
# 43 2026-09-04 11:05:23.063305+01:00
# 44 2026-09-04 11:05:23.063305+01:00
# 45 2026-09-04 11:05:23.063305+01:00
# 46 2026-09-04 11:05:23.063305+01:00
# 47 2026-09-04 11:05:23.063305+01:00
# 48 2026-09-04 11:05:23.063305+01:00
# 49 2026-09-04 11:05:23.063305+01:00
# 50 2026-09-04 11:05:23.063305+01:00

# %%
#To check all columns in alerts_df are reflecting and complete with no extras

for name, df in [('completeness', completeness_alert), ('duration', duration_mismatch_alert),
                  ('reach_sessions', users_exceeds_sessions), ('med_mean', med_mean_alert),
                  ('anomaly', anomaly_alert)]:
    print(name, df.columns.tolist())
# Out:
# completeness ['app_id', 'platform', 'metric_date', 'alert_category', 'alert_type', 'severity', 'metric_name', 'observed_value', 'expected_value', 'deviation_score', 'description', 'detected_at']
# duration ['app_id', 'platform', 'metric_date', 'alert_category', 'alert_type', 'severity', 'metric_name', 'observed_value', 'expected_value', 'deviation_score', 'description', 'detected_at']
# reach_sessions ['app_id', 'platform', 'metric_date', 'alert_category', 'alert_type', 'severity', 'metric_name', 'observed_value', 'expected_value', 'deviation_score', 'description', 'detected_at']
# med_mean ['app_id', 'platform', 'metric_date', 'alert_category', 'alert_type', 'severity', 'metric_name', 'observed_value', 'expected_value', 'deviation_score', 'description', 'detected_at']
# anomaly ['app_id', 'platform', 'metric_date', 'alert_category', 'alert_type', 'severity', 'metric_name', 'observed_value', 'expected_value', 'deviation_score', 'description', 'detected_at']

# %%
#Check alerts_df
alerts_df.head()
#alerts_df['alert_category'].value_counts()
#alerts_df.dtypes
# Out:
#    alert_id app_id platform metric_date alert_category  \
# 0         1   A001      iOS  2025-07-02        anomaly
# 1         2   A001      iOS  2025-07-09        anomaly
# 2         3   A006  Android  2025-06-25        anomaly
# 3         4   A006  Android  2025-07-06        anomaly
# 4         5   A006  Android  2025-07-28        anomaly
#
#                    alert_type  severity                  metric_name  \
# 0  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 1  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 2  reach_users_zscore_outlier   warning  reach_users rolling z-score
# 3  reach_users_zscore_outlier  critical  reach_users rolling z-score
# 4  reach_users_zscore_outlier   warning  reach_users rolling z-score
#
#    observed_value  expected_value  deviation_score  \
# 0          4291.0     2408.714286         5.581063
# 1           851.0     2520.642857        -3.427630
# 2          8918.0    31165.347826        -3.725334
# 3         80213.0    30566.214286         6.656937
# 4         72403.0    32635.714286         3.376455
#
#                                          description  \
# 0  reach_users is more than 3 standard deviations...
# 1  reach_users is more than 3 standard deviations...
# 2  reach_users is more than 3 standard deviations...
# 3  reach_users is more than 3 standard deviations...
# 4  reach_users is more than 3 standard deviations...
#
#                        detected_at
# 0 2026-09-04 11:05:23.063305+01:00
# 1 2026-09-04 11:05:23.063305+01:00
# 2 2026-09-04 11:05:23.063305+01:00
# 3 2026-09-04 11:05:23.063305+01:00
# 4 2026-09-04 11:05:23.063305+01:00

# %%
#grouping alerts_df by alert_category and platform

duckdb.sql("""
SELECT alert_category, platform, COUNT(*) AS alert_count
FROM alerts_df
GROUP BY alert_category, platform
ORDER BY alert_category, platform
""").df()
# Out:
#   alert_category platform  alert_count
# 0        anomaly  Android           30
# 1        anomaly      iOS           21

# %%
#

platform_counts = alerts_df[alerts_df['alert_category'] == 'anomaly']['platform'].value_counts()
platform_counts.plot(kind='bar', title='Anomaly Alerts by Platform')
plt.ylabel('Alert count')
plt.xlabel('Platform')
plt.show()
